# %%
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# %%
X, y = make_blobs(n_samples = 5000, n_features = 5, centers = 15, random_state = 23)

fig = plt.figure(0)
plt.grid(True)
plt.scatter(X[:, 0], X[:, 1])
plt.show()

# %%
import numpy as np
k = 4

clusters = {}
np.random.seed(30)

for idx in range(k):
    center = 2 * (2 * np.random.random((X.shape[1], ))-1)
    points = []
    cluster = {
        'center' : center,
        'points' : []
    }
    clusters[idx] = cluster

print(clusters)
# Out:
# {0: {'center': array([ 0.57657414, -0.47700604,  0.65219162, -1.3453971 ,  1.85043125]), 'points': []}, 1: {'center': array([-0.61335264,  1.96700397, -1.05976842,  0.34277707, -0.37323959]), 'points': []}, 2: {'center': array([-1.45506271,  0.17654515,  0.07270539,  1.06742043,  1.73540057]), 'points': []}, 3: {'center': array([-1.64118647, -1.21691497,  1.97677474, -1.05927801, -1.04405451]), 'points': []}}
